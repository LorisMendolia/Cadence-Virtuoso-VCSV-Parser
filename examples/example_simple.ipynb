# %%
import numpy as np
import matplotlib.pyplot as plt
from vcsv_parser import vcsv_parser

# %%
meta, df = vcsv_parser('test_burst.vcsv')
df
# Out:
#                                  0.0000        0.0003        0.0006  \
# Igain_Fast   Ilin_Slow
# 7.000000e-10 5.000000e-11  3.140706e-12  3.598946e-12  2.252659e-10
#              6.000000e-11  3.140706e-12  3.598948e-12  2.252660e-10
# 8.000000e-10 5.000000e-11  3.140706e-12  3.598910e-12  2.252620e-10
#              6.000000e-11  3.140706e-12  3.598912e-12  2.252622e-10
# 9.000000e-10 5.000000e-11  3.140706e-12  3.598881e-12  2.252589e-10
#              6.000000e-11  3.140706e-12  3.598883e-12  2.252591e-10
#
#                                  0.0009        0.0012        0.0015  \
# Igain_Fast   Ilin_Slow
# 7.000000e-10 5.000000e-11  5.817026e-10  1.048261e-09  8.593009e-10
#              6.000000e-11  5.817041e-10  1.048262e-09  8.593012e-10
# 8.000000e-10 5.000000e-11  6.153046e-10  1.142511e-09  9.302221e-10
#              6.000000e-11  6.153066e-10  1.142511e-09  9.302217e-10
# 9.000000e-10 5.000000e-11  6.486610e-10  1.234755e-09  1.000525e-09
# ...

# %% [markdown]
# Example of selecting a slice for a certain parameter value:

# %%
df_Igain = df.xs((5e-11), level='Ilin_Slow')
df_Igain
# Out:
#                     0.0000        0.0003        0.0006        0.0009  \
# Igain_Fast
# 7.000000e-10  3.140706e-12  3.598946e-12  2.252659e-10  5.817026e-10
# 8.000000e-10  3.140706e-12  3.598910e-12  2.252620e-10  6.153046e-10
# 9.000000e-10  3.140706e-12  3.598881e-12  2.252589e-10  6.486610e-10
#
#                     0.0012        0.0015        0.0018        0.0021  \
# Igain_Fast
# 7.000000e-10  1.048261e-09  8.593009e-10  8.923486e-10  7.795681e-10
# 8.000000e-10  1.142511e-09  9.302221e-10  9.785029e-10  8.097624e-10
# 9.000000e-10  1.234755e-09  1.000525e-09  1.046170e-09  8.429030e-10
#
#                     0.0024        0.0027  ...        0.9972        0.9975  \
# Igain_Fast                                ...
# 7.000000e-10  6.384499e-10  5.467707e-10  ...  3.011514e-11  1.253333e-11
# 8.000000e-10  6.703368e-10  5.790072e-10  ...  6.030560e-11  6.535058e-11
# 9.000000e-10  7.040637e-10  6.111910e-10  ...  1.902151e-10  1.138837e-11
#
# ...

# %% [markdown]
# Example of selecting a single simulation for a tuple of parameter values:

# %%
signal = df.loc[(8e-10,5e-11)]
plt.plot(signal)
